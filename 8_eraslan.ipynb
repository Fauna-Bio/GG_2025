# %% [markdown]
# # Checking Eraslan et al.

# %%
import scanpy as sc
import decoupler as dc
import pandas as pd
import sys
import anndata
import numpy as np

# %% [markdown]
# Read in Eraslan data. (The h5ad from Cellxgene).

# %%
dataset = 'eraslan'
rt = '/home/ec2-user/curation/'
filenames = {'amrute':'ad.h5ad','brener':'ad.h5ad','chaffin':'human_dcm_hcm_scportal_03.17.2022.h5ad','eraslan':'ad.h5ad','hill':'ad.h5ad',
            'litvinukova':'ad.h5ad','kanemaru':'ad.h5ad','kuppe':'ad.h5ad','reichart':'ad.h5ad','selewa':'ad.h5ad',
             'knight_schrijver':'ad.h5ad',
            'sim':'ad.h5ad','simonson':'ICM_scportal_05.24.2022.h5ad','tucker':'healthy_human_4chamber_map_unnormalized_V4.h5ad',
            'linna_kuosmanen':['carebank.h5ad','periheart.h5ad']}

ad_raw = sc.read_h5ad(rt+dataset+'/'+filenames[dataset])

# %% [markdown]
# Point varname to the feature name.

# %%
ad_raw.var.set_index('feature_name',inplace=True)

# %%
ad_raw.raw.var.set_index('feature_name',inplace=True)

# %% [markdown]
# Pseudobulk by relevant categories.

# %%
ad = dc.get_pseudobulk(ad_raw,sample_col='donor_id',groups_col=['tissue','cell_type'],
    mode='mean',
    min_cells=0,
    min_counts=0,use_raw=True)

# %%
ad=ad[ad.obs['sex']=='male']

# %%
# ad.obs['donor_id']

# %%
df  = ad.obs[['donor_id','psbulk_n_cells','tissue','cell_type','sex']].copy()

# %%
x = ad[:,'XIST'].X
df['mean'] = np.array(x)
x = ad[:,'UTY'].X
df['meanuty'] = np.array(x)

# %% [markdown]
# Check male samples (tissue/cell type/donor ID tuples) with the highest XIST expression by mean.  It's predominantly Schwann cells. But, there are some surprises...

# %%
df.sort_values('mean',ascending =False).reset_index(drop=True)[:50]
# Out:
#       donor_id  psbulk_n_cells                           tissue  \
# 0   GTEX-1CAMR             4.0                      skin of leg
# 1   GTEX-1CAMR            32.0                      skin of leg
# 2   GTEX-1HSMQ             8.0             lingula of left lung
# 3   GTEX-1HSMQ           199.0             lingula of left lung
# 4   GTEX-1HSMQ           472.0             lingula of left lung
# 5   GTEX-1HSMQ          8708.0             lingula of left lung
# 6   GTEX-1HSMQ           198.0             lingula of left lung
# 7   GTEX-1HSMQ            13.0                   prostate gland
# 8   GTEX-144GM           500.0      esophagus muscularis mucosa
# 9   GTEX-1I1GU            44.0                   prostate gland
# 10  GTEX-15RIE             6.0                    gastrocnemius
# 11  GTEX-1HSMQ           199.0      esophagus muscularis mucosa
# 12  GTEX-1HSMQ           308.0             lingula of left lung
# 13  GTEX-15RIE            94.0  anterior wall of left ventricle
# 14  GTEX-1HSMQ          2900.0             lingula of left lung
# 15  GTEX-1HSMQ             8.0                    gastrocnemius
# 16  GTEX-1HSMQ            59.0             lingula of left lung
# 17  GTEX-12BJ1            10.0                   prostate gland
# 18  GTEX-1HSMQ            75.0             lingula of left lung
# 19  GTEX-1HSMQ          1278.0             lingula of left lung
# 20  GTEX-1HSMQ            28.0      esophagus muscularis mucosa
# 21  GTEX-1HSMQ           157.0             lingula of left lung
# 22  GTEX-15RIE           138.0  anterior wall of left ventricle
# 23  GTEX-15RIE          2526.0  anterior wall of left ventricle
# 24  GTEX-1HSMQ           205.0                      skin of leg
# 25  GTEX-15CHR           291.0             lingula of left lung
# 26  GTEX-15RIE           291.0                    gastrocnemius
# 27  GTEX-1HSMQ          2536.0      esophagus muscularis mucosa
# 28  GTEX-12BJ1           392.0                   prostate gland
# 29  GTEX-144GM          1090.0      esophagus muscularis mucosa
# 30  GTEX-144GM          2471.0      esophagus muscularis mucosa
# 31  GTEX-1HSMQ          2511.0      esophagus muscularis mucosa
# 32  GTEX-15RIE           691.0  anterior wall of left ventricle
# 33  GTEX-144GM          3877.0      esophagus muscularis mucosa
# 34  GTEX-12BJ1          1651.0                   prostate gland
# 35  GTEX-15RIE          2527.0  anterior wall of left ventricle
# 36  GTEX-15RIE          1991.0  anterior wall of left ventricle
# 37  GTEX-1I1GU          5187.0                   prostate gland
# 38  GTEX-15RIE          4265.0                    gastrocnemius
# 39  GTEX-12BJ1          1640.0                   prostate gland
# 40  GTEX-1I1GU          4129.0                   prostate gland
# 41  GTEX-1HSMQ          2108.0                   prostate gland
# 42  GTEX-15CHR          4901.0             lingula of left lung
# 43  GTEX-1HSMQ          7232.0                    gastrocnemius
# 44  GTEX-12BJ1            10.0                   prostate gland
# 45  GTEX-1I1GU           761.0                   prostate gland
# 46  GTEX-1HSMQ          1268.0                   prostate gland
# 47  GTEX-15CHR            61.0                   prostate gland
# 48  GTEX-1I1GU           110.0                   prostate gland
# 49  GTEX-12BJ1           510.0                   prostate gland
#
#                                   cell_type   sex      mean   meanuty
# 0                   basal cell of epidermis  male  5.750000  0.000000
# 1            epithelial cell of sweat gland  male  1.531250  0.156250
# 2                                    B cell  male  0.500000  0.125000
# 3                 bronchial epithelial cell  male  0.477387  0.190955
# 4                                fibroblast  male  0.358051  0.139831
# 5       epithelial cell of alveolus of lung  male  0.343362  0.265848
# 6                                macrophage  male  0.257576  0.166667
# 7                              Schwann cell  male  0.230769  0.000000
# 8                              Schwann cell  male  0.218000  0.194000
# 9                              Schwann cell  male  0.204545  0.090909
# 10                             Schwann cell  male  0.166667  0.500000
# 11                             Schwann cell  male  0.165829  0.120603
# 12                   respiratory basal cell  male  0.142857  0.370130
# 13                             Schwann cell  male  0.138298  0.085106
# 14                      alveolar macrophage  male  0.133448  0.365862
# 15                             Schwann cell  male  0.125000  0.500000
# 16                         contractile cell  male  0.118644  0.152542
# 17                             Schwann cell  male  0.100000  0.200000
# 18     endothelial cell of lymphatic vessel  male  0.093333  0.146667
# 19        endothelial cell of vascular tree  male  0.036776  0.133803
# 20               interstitial cell of Cajal  male  0.035714  0.500000
# 21                                   T cell  male  0.031847  0.165605
# 22                       smooth muscle cell  male  0.007246  0.246377
# 23                      cardiac muscle cell  male  0.005542  0.816706
# 24           epithelial cell of sweat gland  male  0.004878  0.468293
# 25                               fibroblast  male  0.003436  0.134021
# 26        endothelial cell of vascular tree  male  0.003436  0.206186
# 27                       smooth muscle cell  male  0.003155  0.132886
# 28           smooth muscle cell of prostate  male  0.002551  0.721939
# 29                       smooth muscle cell  male  0.001835  0.144954
# 30                               fibroblast  male  0.001619  0.195872
# 31               enteric smooth muscle cell  male  0.001593  0.162087
# 32                         contractile cell  male  0.001447  0.123010
# 33               enteric smooth muscle cell  male  0.001290  0.236265
# 34      luminal cell of prostate epithelium  male  0.001211  0.895215
# 35                               fibroblast  male  0.001187  0.402454
# 36        endothelial cell of vascular tree  male  0.001005  0.239076
# 37      luminal cell of prostate epithelium  male  0.000771  0.760748
# 38                    skeletal muscle fiber  male  0.000703  0.357562
# 39              epithelial cell of prostate  male  0.000610  0.678049
# 40  basal epithelial cell of prostatic duct  male  0.000484  0.627513
# 41              epithelial cell of prostate  male  0.000474  0.657021
# 42      epithelial cell of alveolus of lung  male  0.000408  0.342175
# 43                    skeletal muscle fiber  male  0.000277  0.589049
# 44                                   B cell  male  0.000000  0.400000
# 45        endothelial cell of vascular tree  male  0.000000  0.411301
# 46        endothelial cell of vascular tree  male  0.000000  0.356467
# 47        endothelial cell of vascular tree  male  0.000000  0.245902
# 48     endothelial cell of lymphatic vessel  male  0.000000  0.336364
# 49        endothelial cell of vascular tree  male  0.000000  0.386275

# %% [markdown]
# A lot of these seem to be from a single donor, and a single sample: the left lung of 1HSMQ. The other 1HSMQ samples (non-Schwann data) have ~noise floor or flat zero for XIST. This is somewhat hard to explain.

# %%
df=ad[ad.obs['donor_id']=='GTEX-1HSMQ'].obs[['donor_id','psbulk_n_cells','tissue','cell_type','sex']].copy()
x = ad[ad.obs['donor_id']=='GTEX-1HSMQ','XIST'].X
df['mean'] = np.array(x)
x = ad[ad.obs['donor_id']=='GTEX-1HSMQ','UTY'].X
df['meanuty'] = np.array(x)

# %%
df.sort_values('mean',ascending =False).reset_index(drop=True)[:60]
# Out:
#       donor_id  psbulk_n_cells                       tissue  \
# 0   GTEX-1HSMQ             8.0         lingula of left lung
# 1   GTEX-1HSMQ           199.0         lingula of left lung
# 2   GTEX-1HSMQ           472.0         lingula of left lung
# 3   GTEX-1HSMQ          8708.0         lingula of left lung
# 4   GTEX-1HSMQ           198.0         lingula of left lung
# 5   GTEX-1HSMQ            13.0               prostate gland
# 6   GTEX-1HSMQ           199.0  esophagus muscularis mucosa
# 7   GTEX-1HSMQ           308.0         lingula of left lung
# 8   GTEX-1HSMQ          2900.0         lingula of left lung
# 9   GTEX-1HSMQ             8.0                gastrocnemius
# 10  GTEX-1HSMQ            59.0         lingula of left lung
# 11  GTEX-1HSMQ            75.0         lingula of left lung
# 12  GTEX-1HSMQ          1278.0         lingula of left lung
# 13  GTEX-1HSMQ            28.0  esophagus muscularis mucosa
# 14  GTEX-1HSMQ           157.0         lingula of left lung
# 15  GTEX-1HSMQ           205.0                  skin of leg
# 16  GTEX-1HSMQ          2536.0  esophagus muscularis mucosa
# 17  GTEX-1HSMQ          2511.0  esophagus muscularis mucosa
# 18  GTEX-1HSMQ          2108.0               prostate gland
# 19  GTEX-1HSMQ          7232.0                gastrocnemius
# 20  GTEX-1HSMQ          3184.0               prostate gland
# 21  GTEX-1HSMQ            72.0               prostate gland
# 22  GTEX-1HSMQ          1886.0               prostate gland
# 23  GTEX-1HSMQ            93.0               prostate gland
# 24  GTEX-1HSMQ            54.0               prostate gland
# 25  GTEX-1HSMQ          1268.0               prostate gland
# 26  GTEX-1HSMQ             2.0  esophagus muscularis mucosa
# 27  GTEX-1HSMQ           178.0               prostate gland
# 28  GTEX-1HSMQ           706.0                  skin of leg
# 29  GTEX-1HSMQ           499.0                  skin of leg
# 30  GTEX-1HSMQ           227.0                  skin of leg
# 31  GTEX-1HSMQ           105.0                  skin of leg
# 32  GTEX-1HSMQ           162.0                  skin of leg
# 33  GTEX-1HSMQ            13.0                  skin of leg
# 34  GTEX-1HSMQ           261.0                  skin of leg
# 35  GTEX-1HSMQ           378.0                  skin of leg
# 36  GTEX-1HSMQ            48.0                  skin of leg
# 37  GTEX-1HSMQ           290.0                  skin of leg
# 38  GTEX-1HSMQ             3.0               prostate gland
# 39  GTEX-1HSMQ           183.0                  skin of leg
# 40  GTEX-1HSMQ          1793.0                  skin of leg
# 41  GTEX-1HSMQ            74.0                  skin of leg
# 42  GTEX-1HSMQ           714.0               prostate gland
# 43  GTEX-1HSMQ           671.0               prostate gland
# 44  GTEX-1HSMQ            53.0               prostate gland
# 45  GTEX-1HSMQ            14.0               prostate gland
# 46  GTEX-1HSMQ            21.0               prostate gland
# 47  GTEX-1HSMQ            15.0               prostate gland
# 48  GTEX-1HSMQ             6.0         lingula of left lung
# 49  GTEX-1HSMQ             2.0         lingula of left lung
# 50  GTEX-1HSMQ            34.0         lingula of left lung
# 51  GTEX-1HSMQ            66.0  esophagus muscularis mucosa
# 52  GTEX-1HSMQ           166.0  esophagus muscularis mucosa
# 53  GTEX-1HSMQ           299.0  esophagus muscularis mucosa
# 54  GTEX-1HSMQ           149.0  esophagus muscularis mucosa
# 55  GTEX-1HSMQ           588.0  esophagus muscularis mucosa
# 56  GTEX-1HSMQ          1284.0  esophagus muscularis mucosa
# 57  GTEX-1HSMQ          5103.0  esophagus muscularis mucosa
# 58  GTEX-1HSMQ           649.0  esophagus muscularis mucosa
# 59  GTEX-1HSMQ           368.0  esophagus muscularis mucosa
#
#                                   cell_type   sex      mean   meanuty
# 0                                    B cell  male  0.500000  0.125000
# 1                 bronchial epithelial cell  male  0.477387  0.190955
# 2                                fibroblast  male  0.358051  0.139831
# 3       epithelial cell of alveolus of lung  male  0.343362  0.265848
# 4                                macrophage  male  0.257576  0.166667
# 5                              Schwann cell  male  0.230769  0.000000
# 6                              Schwann cell  male  0.165829  0.120603
# 7                    respiratory basal cell  male  0.142857  0.370130
# 8                       alveolar macrophage  male  0.133448  0.365862
# 9                              Schwann cell  male  0.125000  0.500000
# 10                         contractile cell  male  0.118644  0.152542
# 11     endothelial cell of lymphatic vessel  male  0.093333  0.146667
# 12        endothelial cell of vascular tree  male  0.036776  0.133803
# 13               interstitial cell of Cajal  male  0.035714  0.500000
# 14                                   T cell  male  0.031847  0.165605
# 15           epithelial cell of sweat gland  male  0.004878  0.468293
# 16                       smooth muscle cell  male  0.003155  0.132886
# 17               enteric smooth muscle cell  male  0.001593  0.162087
# 18              epithelial cell of prostate  male  0.000474  0.657021
# 19                    skeletal muscle fiber  male  0.000277  0.589049
# 20      luminal cell of prostate epithelium  male  0.000000  0.608354
# 21                                   T cell  male  0.000000  0.291667
# 22  basal epithelial cell of prostatic duct  male  0.000000  0.539236
# 23                         contractile cell  male  0.000000  0.268817
# 24     endothelial cell of lymphatic vessel  male  0.000000  0.129630
# 25        endothelial cell of vascular tree  male  0.000000  0.356467
# 26                                   B cell  male  0.000000  0.000000
# 27                               macrophage  male  0.000000  0.286517
# 28        endothelial cell of vascular tree  male  0.000000  0.301700
# 29                          skin fibroblast  male  0.000000  0.268537
# 30                     sebaceous gland cell  male  0.000000  0.590308
# 31     professional antigen presenting cell  male  0.000000  0.295238
# 32                       melanocyte of skin  male  0.000000  0.302469
# 33                                mast cell  male  0.000000  0.461538
# 34                             keratinocyte  male  0.000000  0.390805
# 35                           epidermal cell  male  0.000000  0.267196
# 36                epidermal Langerhans cell  male  0.000000  0.416667
# 37     endothelial cell of lymphatic vessel  male  0.000000  0.268966
# 38                                mast cell  male  0.000000  0.000000
# 39                         contractile cell  male  0.000000  0.284153
# 40                  basal cell of epidermis  male  0.000000  0.392638
# 41                                   T cell  male  0.000000  0.297297
# 42           smooth muscle cell of prostate  male  0.000000  0.404762
# 43                          skin fibroblast  male  0.000000  0.333830
# 44                               neutrophil  male  0.000000  0.245283
# 45                      neuroendocrine cell  male  0.000000  0.142857
# 46                                   B cell  male  0.000000  0.380952
# 47                         mature NK T cell  male  0.000000  0.266667
# 48                      elicited macrophage  male  0.000000  0.166667
# 49                         mature NK T cell  male  0.000000  0.500000
# 50                                mast cell  male  0.000000  0.147059
# 51                                   T cell  male  0.000000  0.257576
# 52                                adipocyte  male  0.000000  0.560241
# 53                         contractile cell  male  0.000000  0.197324
# 54                           dendritic cell  male  0.000000  0.187919
# 55     endothelial cell of lymphatic vessel  male  0.000000  0.236395
# 56        endothelial cell of vascular tree  male  0.000000  0.279595
# 57                               fibroblast  male  0.000000  0.167157
# 58                               macrophage  male  0.000000  0.175655
# 59                                mast cell  male  0.000000  0.133152

# %%
df.sort_values('mean',ascending =False).reset_index(drop=True)[60:]
# Out:
#       donor_id  psbulk_n_cells                       tissue  \
# 60  GTEX-1HSMQ             8.0  esophagus muscularis mucosa
# 61  GTEX-1HSMQ             7.0  esophagus muscularis mucosa
# 62  GTEX-1HSMQ            12.0  esophagus muscularis mucosa
# 63  GTEX-1HSMQ            18.0                gastrocnemius
# 64  GTEX-1HSMQ           117.0                gastrocnemius
# 65  GTEX-1HSMQ             6.0                gastrocnemius
# 66  GTEX-1HSMQ            62.0                gastrocnemius
# 67  GTEX-1HSMQ           360.0                gastrocnemius
# 68  GTEX-1HSMQ          1196.0                gastrocnemius
# 69  GTEX-1HSMQ            89.0                gastrocnemius
# 70  GTEX-1HSMQ             3.0                gastrocnemius
# 71  GTEX-1HSMQ             2.0                gastrocnemius
# 72  GTEX-1HSMQ            18.0                gastrocnemius
# 73  GTEX-1HSMQ            84.0                gastrocnemius
# 74  GTEX-1HSMQ          1027.0                gastrocnemius
# 75  GTEX-1HSMQ           268.0                gastrocnemius
# 76  GTEX-1HSMQ           342.0                gastrocnemius
# 77  GTEX-1HSMQ            42.0                gastrocnemius
# 78  GTEX-1HSMQ            17.0                  skin of leg
#
#                                cell_type   sex  mean   meanuty
# 60                      mature NK T cell  male   0.0  0.000000
# 61                                neuron  male   0.0  0.714286
# 62  professional antigen presenting cell  male   0.0  0.666667
# 63                                T cell  male   0.0  0.111111
# 64                      contractile cell  male   0.0  0.230769
# 65                        dendritic cell  male   0.0  1.000000
# 66  endothelial cell of lymphatic vessel  male   0.0  0.338710
# 67     endothelial cell of vascular tree  male   0.0  0.258333
# 68                      fast muscle cell  male   0.0  0.346154
# 69                            macrophage  male   0.0  0.359551
# 70                             mast cell  male   0.0  0.666667
# 71                      mature NK T cell  male   0.0  0.000000
# 72                            neutrophil  male   0.0  0.277778
# 73  professional antigen presenting cell  male   0.0  0.345238
# 74            skeletal muscle fibroblast  male   0.0  0.345667
# 75        skeletal muscle satellite cell  male   0.0  0.208955
# 76                      slow muscle cell  male   0.0  0.283626
# 77                subcutaneous adipocyte  male   0.0  0.285714
# 78                subcutaneous adipocyte  male   0.0  0.058824
